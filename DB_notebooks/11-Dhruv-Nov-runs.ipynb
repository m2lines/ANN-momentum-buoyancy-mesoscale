# %%
import sys
sys.path.append('../src/training-on-CM2.6/')
# %load_ext autoreload
# %autoreload 3

import xarray as xr
import matplotlib.pyplot as plt
from helpers.computational_tools import *


from helpers.collection_of_experiments import CollectionOfExperiments
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 8
#       6 import xarray as xr
#       7 import matplotlib.pyplot as plt
# ----> 8 from helpers.computational_tools import *
#      11 from helpers.collection_of_experiments import CollectionOfExperiments
#
# ModuleNotFoundError: No module named 'helpers.computational_tools'

# %%
ds = CollectionOfExperiments.init_folder('/scratch/pp2681/mom6/OM4_SIS2')

# %%
ds += CollectionOfExperiments.init_folder('/scratch/db194/OM4')

# %%
ds.exps
# Out:
# ['unparameterized-0.09',
#  'unparameterized',
#  'ZB20-Reynolds',
#  'ANN-FGR-2',
#  'ANN-WENO7-FGR3-scaling-0.75',
#  'ZB20-Klower',
#  'ANN-5x5-Klower',
#  'ANN-3x3-32-32',
#  'WENO7',
#  'ZB20-Smooth-1.0',
#  'vert-diff',
#  'JHAH15',
#  'ANN-Taper',
#  'ANN-strain',
#  'unparameterized-OM5',
#  'ZB20-Smooth-2.5',
#  'ANN-3x3-EXP2',
#  'ANN-redline',
#  'ANN-greenline',
#  'ANN-calibrated-dt',
#  'ANN-WENO7-FGR3',
#  'GM',
#  'ANN-default-plus-dEdt',
#  'GM-ANN',
#  'ANN-WENO7',
#  'SSMh',
#  'ANN-1x1',
#  'SSMh-cumsum',
#  'DMM-R',
#  'eANN',
#  'ANN-WENO7-FGR3-scaling-1.5',
#  'unparameterized-0.03',
#  'ANN-SGS',
#  'test_ANN_20Nov']

# %%
ds.plot_series(['unparameterized', 'ANN-greenline', 'test_ANN_20Nov', 'GM'], ['Unparameterized', 'ANN momentum', 'ANN buoyancy', 'GM'])

# %%
ds.plot_temp(['unparameterized', 'ANN-greenline', 'test_ANN_20Nov', 'GM'], ['Unparameterized', 'ANN momentum', 'ANN buoyancy', 'GM'], plot_type='response')

# %% [markdown]
# # T

# %%
ds.plot_temp(['unparameterized', 'ANN-greenline', 'test_ANN_20Nov', 'GM'], ['Unparameterized', 'ANN momentum', 'ANN buoyancy', 'GM'], plot_type='response', zl=11)

# %%
ds.plot_temp(['unparameterized', 'ANN-greenline', 'test_ANN_20Nov', 'GM'], ['Unparameterized', 'ANN momentum', 'ANN buoyancy', 'GM'], plot_type='response', zl=20)

# %% [markdown]
# # S

# %%
ds.plot_so(['unparameterized', 'ANN-greenline', 'test_ANN_20Nov', 'GM'], ['Unparameterized', 'ANN momentum', 'ANN buoyancy', 'GM'], plot_type='response', zl=0)

# %%
ds.plot_so(['unparameterized', 'ANN-greenline', 'test_ANN_20Nov', 'GM'], ['Unparameterized', 'ANN momentum', 'ANN buoyancy', 'GM'], plot_type='response', zl=11)

# %% [markdown]
# # MLD

# %%
ds.plot_MLD_summer(['unparameterized', 'ANN-greenline', 'test_ANN_20Nov', 'GM'], ['Unparameterized', 'ANN momentum', 'ANN buoyancy', 'GM'], plot_type='response', projection='2D')

# %%
ds.plot_MLD_winter(['unparameterized', 'ANN-greenline', 'test_ANN_20Nov', 'GM'], ['Unparameterized', 'ANN momentum', 'ANN buoyancy', 'GM'], plot_type='response', projection='2D')

# %% [markdown]
# # SSH STD

# %%
ds.plot_ssh_std(['unparameterized', 'ANN-greenline', 'test_ANN_20Nov', 'GM'], ['Unparameterized', 'ANN momentum', 'ANN buoyancy', 'GM'], plot_type='response', projection='3D', select=select_globe)

# %% [markdown]
# # Eddies

# %%
ds.plot_KE_spectrum(['unparameterized', 'ANN-greenline', 'test_ANN_20Nov', 'GM', 'obs'], ['Unparameterized', 'ANN momentum', 'ANN buoyancy', 'GM', 'Observations'])
# Out:
# Reading last year...
# Selecting last year instead
# Reading last year...

# %%
ds.plot_geovel(['unparameterized', 'ANN-greenline', 'test_ANN_20Nov', 'GM'], ['Unparameterized', 'ANN momentum', 'ANN buoyancy', 'GM'], plot_type='default', select=select_NA_large, projection='3D')

# %%
ds.plot_geovel(['unparameterized', 'ANN-greenline', 'test_ANN_20Nov', 'GM'], ['Unparameterized', 'ANN momentum', 'ANN buoyancy', 'GM'], plot_type='default', select=select_Pacific, projection='3D')

# %%
ds.plot_geovel(['unparameterized', 'ANN-greenline', 'test_ANN_20Nov', 'GM'], ['Unparameterized', 'ANN momentum', 'ANN buoyancy', 'GM'], plot_type='default', select=select_SO_right, projection='3D')
