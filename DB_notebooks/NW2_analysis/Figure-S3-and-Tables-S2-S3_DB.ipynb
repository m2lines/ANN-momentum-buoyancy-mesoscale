# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
import cmocean
import os

import sys; sys.path.append('../src/training-on-CM2.6')

from helpers.plot_helpers import default_rcParams

# %load_ext autoreload
# %autoreload 2
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Computing crossections of 1000-days average interfaces

# %%
from functools import cache
@cache
def interface(exp='R4-long/bare', lon=0, layer=None):
    base_path = '/scratch/pp2681/mom6/Neverworld2/simulations'
    if exp=='R32':
        ds = xr.open_mfdataset(f'{base_path}/R32/longmean*.nc', decode_times=False)
    else:
        try:
            ds = xr.open_dataset(f'{base_path}/{exp}/output/longmean_00029050.nc', decode_times=False)
        except:
            try:
                # For Dhruv runs
                ds = xr.open_dataset(f'{base_path}/{exp}/longmean_00040050.nc', decode_times=False)
            except:
                pass
                                                                                                                                                
    e = ds.e
    
    if lon is not None:
        # lon=0,15,30,45
        if lon == 0:
            e = e.isel(xh=0)
        else:
            e = e.interp(xh=lon)
    
    if layer is not None:
        # layer = 0 is ssh
        e = e.isel(zi=layer)

    return e.mean('time').compute()

# %%
def interfaces(exp='R4-long/bare', lon=0, layer=None, lat_max=None):
    '''
    Simple wrapper returning hires and lores interfaces
    '''
    hires = interface('R32', lon=lon, layer=layer).sel(yh=slice(None,lat_max))
    lores = interface(exp, lon=lon, layer=layer).sel(yh=slice(None,lat_max))

    if lon is None:
        factor = len(hires.xh) // len(lores.xh)
        return hires.coarsen({'xh': factor, 'yh': factor}).mean().interp(xh=lores.xh, yh=lores.yh), lores
    elif layer is None:
        return hires.interp(yh=lores.yh), lores
    else:
        print('Not implemented')

def rmse(hires, lores):
    error = (lores - hires)
    if 'zi' in error.dims:
        error = error.isel(zi=slice(0,15))
    RMSE = np.sqrt((error**2).mean()) # RMSE in metres
    return round(float(RMSE),3)

# %%
# Test values
print(rmse(*interfaces(lon=0)))
print(rmse(*interfaces(lon=15)))
print(rmse(*interfaces(lon=30)))
print(rmse(*interfaces(lon=45)))
print(rmse(*interfaces(lon=None,layer=0)))
print(rmse(*interfaces(lon=None,layer=None)))
# Out:
# 52.14
# 42.119
# 40.3
# 34.63
# 0.101
# 36.84

# %% [markdown]
# # Interface plotting function

# %%
def plot_interfaces(hires, lores):
    for zi in range(15):
        lores.isel(zi=zi).plot(ls='--', color='blue', lw=2)
        hires.isel(zi=zi).plot(ls='-', color='k', lw=2, alpha=0.5)
    hires.isel(zi=-1).plot(color='k') # show bathymetry 
    
    RMSE = rmse(hires,lores)
    plt.text(0.7,0.1,'RMSE=\n'+"{:.1f}".format(RMSE)+'$\,\mathrm{m}$', fontsize=15, transform = plt.gca().transAxes)
    plt.xlabel('Latitude')
    plt.yticks(np.arange(-4000,1000,1000), np.arange(4000,-1000,-1000))
    plt.ylabel('Depth [m]')
    plt.title('')

# %% [markdown]
# # Figure S3

# %%
from matplotlib import gridspec
default_rcParams({'font.size': 15})
fig = plt.figure(figsize=(12,8))
gs = gridspec.GridSpec(2, 3, figure=fig, wspace=0.3, hspace=0.3)

kw = {'lon': 0, 'lat_max': None}

plt.sca(fig.add_subplot(gs[0, 0]))
plot_interfaces(*interfaces('R4-long/bare', **kw))
plt.title('Control($1/4^\circ$)')
plt.xlabel('')

plt.sca(fig.add_subplot(gs[1, 0]))
plot_interfaces(*interfaces('R4-ANN/May22-Coriolis-upd', **kw))
plt.title('ANN($1/4^\circ$)')

kw = {'lon': 45, 'lat_max': None}
plt.sca(fig.add_subplot(gs[0, 1:]))
plot_interfaces(*interfaces('R4-long/bare', **kw))
plt.title('Control($1/4^\circ$)')
plt.ylabel('')
plt.xlabel('')
plt.grid()

plt.sca(fig.add_subplot(gs[1, 1:]))
plot_interfaces(*interfaces('R4-ANN/May22-Coriolis-upd', **kw))
plt.title('ANN($1/4^\circ$)')
plt.ylabel('')
plt.grid()


plt.tight_layout()
#plt.savefig('/home/pp2681/MOM6-examples/src/MOM6/experiments/ANN-Results/notebooks-paper/figures/interfaces_lon_0_lon_45_NW2-upd.pdf')

# %%
from matplotlib import gridspec
default_rcParams({'font.size': 15})
fig = plt.figure(figsize=(12,16))
gs = gridspec.GridSpec(4, 3, figure=fig, wspace=0.3, hspace=0.3)

kw = {'lon': 0, 'lat_max': None}

plt.sca(fig.add_subplot(gs[0, 0]))
plot_interfaces(*interfaces('R4-long/bare', **kw))
plt.title('Control($1/4^\circ$)')
plt.xlabel('')

plt.sca(fig.add_subplot(gs[1, 0]))
plot_interfaces(*interfaces('R4-ANN/May22-Coriolis-upd', **kw))
plt.title('ANN-Pavel($1/4^\circ$)')
plt.xlabel('')

plt.sca(fig.add_subplot(gs[2, 0]))
plot_interfaces(*interfaces('Dhruv/R4/ANN_c2p5', **kw))
plt.title('ANN-Dhruv($1/4^\circ$)')
plt.xlabel('')

plt.sca(fig.add_subplot(gs[3, 0]))
plot_interfaces(*interfaces('Dhruv/R4/ANN_c2p5_mom', **kw))
plt.title('ANN-Pavel+ANN-Dhruv($1/4^\circ$)')

kw = {'lon': 45, 'lat_max': None}
plt.sca(fig.add_subplot(gs[0, 1:]))
plot_interfaces(*interfaces('R4-long/bare', **kw))
plt.title('Control($1/4^\circ$)')
plt.ylabel('')
plt.xlabel('')
plt.grid()

plt.sca(fig.add_subplot(gs[1, 1:]))
plot_interfaces(*interfaces('R4-ANN/May22-Coriolis-upd', **kw))
plt.title('ANN-Pavel($1/4^\circ$)')
plt.ylabel('')
plt.xlabel('')
plt.grid()

plt.sca(fig.add_subplot(gs[2, 1:]))
plot_interfaces(*interfaces('Dhruv/R4/ANN_c2p5', **kw))
plt.title('ANN-Dhruv($1/4^\circ$)')
plt.ylabel('')
plt.xlabel('')
plt.grid()

plt.sca(fig.add_subplot(gs[3, 1:]))
plot_interfaces(*interfaces('Dhruv/R4/ANN_c2p5_mom', **kw))
plt.title('ANN-Pavel+ANN-Dhruv($1/4^\circ$)')
plt.ylabel('')
plt.grid()


plt.tight_layout()
#plt.savefig('/home/pp2681/MOM6-examples/src/MOM6/experiments/ANN-Results/notebooks-paper/figures/interfaces_lon_0_lon_45_NW2-upd.pdf')

# %%
from matplotlib import gridspec
default_rcParams({'font.size': 15})
fig = plt.figure(figsize=(12,8))
gs = gridspec.GridSpec(2, 3, figure=fig, wspace=0.3, hspace=0.3)

kw = {'lon': 0, 'lat_max': None}

plt.sca(fig.add_subplot(gs[0, 0]))
plot_interfaces(*interfaces('R2-WENO/WENO7', **kw))
plt.title('WENO7($1/2^\circ$)')
plt.xlabel('')

plt.sca(fig.add_subplot(gs[1, 0]))
plot_interfaces(*interfaces('Dhruv/R2-WENO/ANN_c2p0', **kw))
plt.title('WENO7+ANN-Dhruv($1/2^\circ$)')

kw = {'lon': 45, 'lat_max': None}
plt.sca(fig.add_subplot(gs[0, 1:]))
plot_interfaces(*interfaces('R2-WENO/WENO7', **kw))
plt.title('WENO7($1/2^\circ$)')
plt.ylabel('')
plt.xlabel('')
plt.grid()

plt.sca(fig.add_subplot(gs[1, 1:]))
plot_interfaces(*interfaces('Dhruv/R2-WENO/ANN_c2p0', **kw))
plt.title('WENO7+ANN-Dhruv($1/2^\circ$)')
plt.ylabel('')
plt.grid()


plt.tight_layout()
#plt.savefig('/home/pp2681/MOM6-examples/src/MOM6/experiments/ANN-Results/notebooks-paper/figures/interfaces_lon_0_lon_45_NW2-upd.pdf')

# %% [markdown]
# # Table S2

# %%
# 1/4 degree resolution
for exp, label in zip(['R4-long/bare', 'R4-long/Yankovsky23-0.3', 'R4-long/Reynolds-newest-code', 'R4-ANN/May22-Coriolis-upd'], ['Control', 'Yankovsky24', 'ZB20-Reynolds', 'ANN']):
    str = label
    for lon in [0,15,30,45]:
        error = rmse(*interfaces(exp=exp,lon=lon))
        str = str + ' %.1f ' % error
    print(str)
# Out:
# Control 52.1  42.1  40.3  34.6
# Yankovsky24 27.8  23.0  20.7  21.3
# ZB20-Reynolds 26.9  21.0  18.4  18.5
# ANN 29.2  20.0  16.7  19.7

# %%
# 1/3 degree resolution
for exp, label in zip(['R3-long/bare', 'R3-long/Yankovsky24', 'R3-long/ZB20-Reynolds', 'R3-ANN/May22-Coriolis-upd'], ['Control', 'Yankovsky24', 'ZB20-Reynolds', 'ANN']):
    str = label
    for lon in [0,15,30,45]:
        error = rmse(*interfaces(exp=exp,lon=lon))
        str = str + ' %.1f ' % error
    print(str)
# Out:
# Control 51.3  46.8  49.1  36.8
# Yankovsky24 33.5  31.6  29.9  27.4
# ZB20-Reynolds 32.7  25.4  26.1  21.6
# ANN 35.0  24.3  30.9  28.6

# %%
# 1/6 degree resolution
for exp, label in zip(['R6/bare', 'R6/Yankovsky23', 'R6/ZB20-Reynolds', 'R6/ANN'], 
                      ['Control', 'Yankovsky24', 'ZB20-Reynolds', 'ANN']):
    str = label
    for lon in [0,15,30,45]:
        error = rmse(*interfaces(exp=exp,lon=lon))
        str = str + ' %.1f ' % error
    print(str)
# Out:
# Control 42.7  30.7  31.8  26.7
# Yankovsky24 26.2  22.3  16.1  16.8
# ZB20-Reynolds 27.7  24.5  18.9  18.4
# ANN 23.5  18.8  13.8  14.6

# %% [markdown]
# # Table S3

# %%
# Compute ACC transport from instantaneous snapshots
@cache
def ACC(exp='R4-long/bare'):
    base_path = '/scratch/pp2681/mom6/Neverworld2/simulations'
    if exp=='R32':
        ds = xr.open_mfdataset(f'{base_path}/R32/snapshots*.nc', decode_times=False).isel(time=slice(None,None,6))
        static = xr.open_dataset(f'{base_path}/R32/static.nc', decode_times=False)
    else:
        for file in ['snapshots_00029000.nc','snapshots_00029010.nc', 'snapshots_00029020.nc', 'snapshots_00029025.nc', 'snapshots_00029030.nc']:
            try:
                ds = xr.open_dataset(f'{base_path}/{exp}/output/{file}', decode_times=False).sel(time=slice(29200,None))
                static = xr.open_dataset(f'/scratch/pp2681/mom6/Neverworld2/simulations/{exp}/output/static.nc', decode_times=False)
            except:
                pass
    
    u = ds.u.sel(xq=0).load()
    h = ds.h.isel(xh=[0,-1]).load()
    h_interp = (h.isel(xh=0) + h.isel(xh=-1)) * 0.5
    dyCu = static.dyCu.sel(xq=0).load()

    transport = u*h_interp*dyCu
    
    return transport.sum(['yh', 'zl']) * 1e-6

# %%
# 1/4 degree resolution
for exp, label in zip(['R32', 'R4-long/bare', 'R4-long/Yankovsky23-0.3', 'R4-long/Reynolds-newest-code', 'R4-ANN/May22-Coriolis-upd'], ['1/32-degree', 'Control', 'Yankovsky24', 'ZB20-Reynolds', 'ANN']):
    str = label
    transport = ACC(exp).mean()
    str = str + ' %.1f ' % transport
    print(str)
# Out:
# 1/32-degree 235.3
# Control 245.1
# Yankovsky24 229.9
# ZB20-Reynolds 225.4
# ANN 236.9

# %%
# 1/3 resolution
for exp, label in zip(['R3-long/bare', 'R3-long/Yankovsky24', 'R3-long/ZB20-Reynolds', 'R3-ANN/May22-Coriolis-upd'], ['Control', 'Yankovsky24', 'ZB20-Reynolds', 'ANN']):
    str = label
    transport = ACC(exp).mean()
    str = str + ' %.1f ' % transport
    print(str)
# Out:
# Control 242.7
# Yankovsky24 237.4
# ZB20-Reynolds 230.2
# ANN 241.6

# %%
# 1/6 resolution
for exp, label in zip(['R6/bare', 'R6/Yankovsky23', 'R6/ZB20-Reynolds', 'R6/ANN'], 
                      ['Control', 'Yankovsky24', 'ZB20-Reynolds', 'ANN']):

    str = label
    transport = ACC(exp).mean()
    str = str + ' %.1f ' % transport
    print(str)
# Out:
# Control 243.3
# Yankovsky24 230.4
# ZB20-Reynolds 219.5
# ANN 228.8

# %% [markdown]
# # Time series (not in the paper)

# %%
default_rcParams({'figure.subplot.wspace': 0.05, 'figure.subplot.hspace': 0.15, 'font.size': 12})
def plot_timeseries(exps=['R4-long/bare'], labels=None, tmax=30000):
    plt.figure(figsize=(10,6))
    if labels is None:
        labels=exps
    for exp, label in zip(exps, labels):
        try:
            ds = xr.open_dataset(f'/scratch/pp2681/mom6/Neverworld2/simulations/{exp}/output/ocean.stats.nc', decode_times=False)
        except:
            ds = xr.open_dataset(f'/scratch/pp2681/mom6/Neverworld2/simulations/{exp}/ocean.stats.nc', decode_times=False)
        ticks = [0,int(tmax/3),int(tmax*2/3),int(tmax)]
        plt.subplot(2,1,1)
        (ds.KE.sum('Layer').groupby('Time').min()).plot()
        plt.xlabel('Days')
        plt.xticks(ticks,ticks)
        plt.axhline(y=2.45e+18, color='k')
        plt.xlim([0,tmax])
        plt.grid()

        plt.subplot(2,1,2)
        (ds.APE.sum('Interface').groupby('Time').min()).plot(label=label)
        plt.xlabel('Days')
        plt.xticks(ticks,ticks)
        plt.axhline(y=0.958e+20, color='k')
        plt.xlim([0,tmax])
        plt.grid()
    plt.tight_layout()
    plt.legend(bbox_to_anchor=(1,1))

# %%
plot_timeseries(['R6/bare', 'R6/Yankovsky23', 'R6/ZB20-Reynolds', 'R6/ANN'], 
                      ['Control', 'Yankovsky24', 'ZB20-Reynolds',  'ANN'])
plt.suptitle('Time series at 1/6-degree resolution')
# Out:
# Text(0.5, 0.98, 'Time series at 1/6-degree resolution')

# %%
plot_timeseries(['R4-long/bare', 'R4-long/Yankovsky23-0.3', 'R4-long/Reynolds-newest-code', 'R4-ANN/May22-Coriolis-upd'], ['Control', 'Yankovsky24', 'ZB20-Reynolds', 'ANN'])
plt.suptitle('Time series at 1/4-degree resolution')
# Out:
# Text(0.5, 0.98, 'Time series at 1/4-degree resolution')

# %%
plot_timeseries(['R4-long/bare', 'R4-ANN/May22-Coriolis-upd', 'Dhruv/R4/ANN_c2p5', 'Dhruv/R4/ANN_c2p5_mom'], ['Control', 'ANN-Pavel', 'ANN-Dhruv', 'ANN-Pavel + ANN-Dhruv'], tmax=45000)
plt.suptitle('Time series at 1/4-degree resolution')
# Out:
# Text(0.5, 0.98, 'Time series at 1/4-degree resolution')

# %%
plot_timeseries(['R2-WENO/WENO7', 'R2-long/bare-stable', 'Dhruv/R2-WENO/ANN_c2p0'], ['WENO7', 'Bare stable', 'WENO7 + ANN-Dhruv'], tmax=45000)
plt.suptitle('Time series at 1/2-degree resolution')
# Out:
# Text(0.5, 0.98, 'Time series at 1/2-degree resolution')

# %%
plot_timeseries(['R2-long/bare-stable', 'R2-long/Reynolds', 'R2-WENO/ANN-WENO7-boundary-cdiss-dissipation', 'R2-WENO/WENO7', 'R2-ANN/May22-Coriolis', 'R2-WENO/ANN-calibrated'], ['Control', 'Reynolds', 'ANN-WENO', 'WENO', 'ANN', 'eANN calibrated'])
plt.suptitle('Time series at 1/2-degree resolution')
# Out:
# Text(0.5, 0.98, 'Time series at 1/2-degree resolution')

# %%
from matplotlib import gridspec
default_rcParams({'font.size': 15})
fig = plt.figure(figsize=(12,8))
gs = gridspec.GridSpec(2, 3, figure=fig, wspace=0.3, hspace=0.3)

kw = {'lon': 0, 'lat_max': None}

plt.sca(fig.add_subplot(gs[0, 0]))
plot_interfaces(*interfaces('R2-long/bare-stable', **kw))
plt.title('Control($1/2^\circ$)')
plt.xlabel('')

plt.sca(fig.add_subplot(gs[1, 0]))
plot_interfaces(*interfaces('R2-WENO/ANN-calibrated', **kw))
plt.title('eANN calibrated($1/2^\circ$)')

kw = {'lon': 45, 'lat_max': None}
plt.sca(fig.add_subplot(gs[0, 1:]))
plot_interfaces(*interfaces('R2-long/bare-stable', **kw))
plt.title('Control($1/2^\circ$)')
plt.ylabel('')
plt.xlabel('')
plt.grid()

plt.sca(fig.add_subplot(gs[1, 1:]))
plot_interfaces(*interfaces('R2-WENO/ANN-calibrated', **kw))
plt.title('eANN calibrated($1/2^\circ$)')
plt.ylabel('')
plt.grid()


plt.tight_layout()

# %%
from matplotlib import gridspec
default_rcParams({'font.size': 15})
fig = plt.figure(figsize=(12,8))
gs = gridspec.GridSpec(2, 4, figure=fig, wspace=0.3, hspace=0.3)

kw = {'lon': 15, 'lat_max': None}

plt.sca(fig.add_subplot(gs[0, :2]))
plot_interfaces(*interfaces('R2-long/bare-stable', **kw))
plt.title('Unparameterized($1/2^\circ$)')
plt.xlabel('')

plt.sca(fig.add_subplot(gs[1, :2]))
plot_interfaces(*interfaces('R2-WENO/ANN-calibrated', **kw))
plt.title('eANN calibrated($1/2^\circ$)')

kw = {'lon': 30, 'lat_max': None}
plt.sca(fig.add_subplot(gs[0, 2:]))
plot_interfaces(*interfaces('R2-long/bare-stable', **kw))
plt.title('Unparameterized($1/2^\circ$)')
plt.ylabel('')
plt.xlabel('')
plt.grid()

plt.sca(fig.add_subplot(gs[1, 2:]))
plot_interfaces(*interfaces('R2-WENO/ANN-calibrated', **kw))
plt.title('eANN calibrated($1/2^\circ$)')
plt.ylabel('')
plt.grid()


plt.tight_layout()

# %%
from matplotlib import gridspec
default_rcParams({'font.size': 15})
fig = plt.figure(figsize=(12,8))
gs = gridspec.GridSpec(2, 4, figure=fig, wspace=0.3, hspace=0.3)

kw = {'lon': 15, 'lat_max': None}

plt.sca(fig.add_subplot(gs[0, :2]))
plot_interfaces(*interfaces('R2-WENO/ANN-noncalibrated', **kw))
plt.title('eANN not calibrated($1/2^\circ$)')
plt.xlabel('')

plt.sca(fig.add_subplot(gs[1, :2]))
plot_interfaces(*interfaces('R2-WENO/ANN-calibrated', **kw))
plt.title('eANN calibrated($1/2^\circ$)')

kw = {'lon': 30, 'lat_max': None}
plt.sca(fig.add_subplot(gs[0, 2:]))
plot_interfaces(*interfaces('R2-WENO/ANN-noncalibrated', **kw))
plt.title('eANN not calibrated($1/2^\circ$)')
plt.ylabel('')
plt.xlabel('')
plt.grid()

plt.sca(fig.add_subplot(gs[1, 2:]))
plot_interfaces(*interfaces('R2-WENO/ANN-calibrated', **kw))
plt.title('eANN calibrated($1/2^\circ$)')
plt.ylabel('')
plt.grid()


plt.tight_layout()

# %%
# 1/2 degree resolution sections
for exp, label in zip(['R2-long/bare-stable', 'R2-long/Reynolds', 'R2-WENO/ANN-WENO7-boundary-cdiss-dissipation', 'R2-WENO/WENO7', 'R2-ANN/May22-Coriolis', 'R2-WENO/ANN-calibrated', 'R2-WENO/ANN-noncalibrated', 'Dhruv/R2-WENO/ANN_c2p0'], ['Control', 'Reynolds', 'ANN-WENO', 'WENO', 'ANN', 'eANN calibrated', 'eANN not calibrated', 'ANN-Dhruv']):
    str = label
    for lon in [0,15,30,45]:
        error = rmse(*interfaces(exp=exp,lon=lon))
        str = str + ' %.1f ' % error
    print(str)
# Out:
# Control 59.1  54.0  77.5  48.0
# Reynolds 47.6  41.7  61.7  43.3
# ANN-WENO 64.1  37.9  42.7  44.2
# WENO 52.5  42.6  55.6  45.4
# ANN 75.8  42.4  74.0  55.9
# eANN calibrated 48.8  32.8  35.0  38.7
# eANN not calibrated 69.1  44.5  73.3  55.4
# ANN-Dhruv 73.1  36.4  41.7  34.4

# %%
# 1/2 degree SSH
for exp, label in zip(['R2-long/bare-stable', 'R2-long/Reynolds', 'R2-WENO/ANN-WENO7-boundary-cdiss-dissipation', 'R2-WENO/WENO7', 'R2-ANN/May22-Coriolis', 'R2-WENO/ANN-calibrated', 'R4-ANN/May22-Coriolis-upd'], ['Control', 'Reynolds', 'ANN-WENO', 'WENO', 'ANN', 'eANN calibrated', 'ANN 1/4']):
    str = label
    error = rmse(*interfaces(exp=exp,lon=None, layer=0))
    str = str + ' %.3f ' % error
    print(str)
# Out:
# Control 0.161
# Reynolds 0.133
# ANN-WENO 0.138
# WENO 0.143
# ANN 0.167
# eANN calibrated 0.111
# ANN 1/4 0.073

# %%
# 1/2 degree 3D interfaces
for exp, label in zip(['R2-long/bare-stable', 'R2-long/Reynolds', 'R2-WENO/ANN-WENO7-boundary-cdiss-dissipation', 'R2-WENO/WENO7', 'R2-ANN/May22-Coriolis', 'R2-WENO/ANN-calibrated', 'R4-ANN/May22-Coriolis-upd'], ['Control', 'Reynolds', 'ANN-WENO', 'WENO', 'ANN', 'eANN calibrated', 'ANN 1/4']):
    str = label
    error = rmse(*interfaces(exp=exp,lon=None, layer=None))
    str = str + ' %.3f ' % error
    print(str)
# Out:
# Control 54.351
# Reynolds 45.264
# ANN-WENO 42.905
# WENO 45.312
# ANN 54.483
# eANN calibrated 35.683
# ANN 1/4 20.607

# %%
# 1/32-degree 235.3 
ACC('R2-long/bare-stable').mean()
# Out:
# <xarray.DataArray ()> Size: 8B
# array(257.76235896)
# Coordinates:
#     xq       float64 8B 0.0

# %%
ACC('R2-WENO/ANN-calibrated').mean()
# Out:
# <xarray.DataArray ()> Size: 8B
# array(236.10567402)
# Coordinates:
#     xq       float64 8B 0.0

# %% [markdown]
# # Analysis of snapshots

# %%
ds = xr.open_dataset('/scratch/pp2681/mom6/Neverworld2/simulations/R2-WENO/ANN-calibrated/output/snapshots_00029000.nc', decode_times=False)
static = xr.open_dataset('/scratch/pp2681/mom6/Neverworld2/simulations/R2-WENO/ANN-calibrated/output/static.nc', decode_times=False)

# %%
plt.figure(figsize=(16,8))
zl = 3
plt.subplot(1,4,1)
ds.u[0][zl].plot(vmin=-0.5, cbar_kwargs={'shrink': 0.65})
plt.gca().set_aspect(1)
plt.title('u')

plt.subplot(1,4,2)
ds.v[0][zl].plot(vmin=-0.5, cbar_kwargs={'shrink': 0.65})
plt.gca().set_aspect(1)
plt.title('v')

plt.subplot(1,4,3)
ds.RV[0][zl].plot(vmin=-1e-5, cbar_kwargs={'shrink': 0.65})
plt.gca().set_aspect(1)
plt.title('RV')

plt.subplot(1,4,4)
(ds.h[0][zl]).plot(cbar_kwargs={'shrink': 0.65})
plt.gca().set_aspect(1)
plt.title('h')

plt.tight_layout()

# %%
plt.figure(figsize=(12,8))
zl = 3
plt.subplot(1,3,1)
ds.u[0][zl].plot(vmin=-0.5, cbar_kwargs={'shrink': 0.65})
plt.gca().set_aspect(1)
plt.title('u')

plt.subplot(1,3,2)
ds.v[0][zl].plot(vmin=-0.5, cbar_kwargs={'shrink': 0.65})
plt.gca().set_aspect(1)
plt.title('v')

plt.subplot(1,3,3)
(ds.h[0][zl]).plot(cbar_kwargs={'shrink': 0.65})
plt.gca().set_aspect(1)
plt.title('h')

plt.tight_layout()
